# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data: Monthly sales revenue over two years
months = pd.date_range(start='2023-01-01', periods=24, freq='M')
sales = [50, 48, 55, 60, 62, 65, 70, 72, 74, 76, 78, 90, 
         52, 50, 57, 62, 64, 67, 72, 74, 76, 78, 80, 95]

plt.plot(months, sales)
plt.title('Monthly Sales Revenue')
plt.xlabel('Month')
plt.ylabel('Sales Revenue ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9996\1187996634.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range(start='2023-01-01', periods=24, freq='M')
