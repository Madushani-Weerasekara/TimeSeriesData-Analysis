# %%
# plot the original data

import matplotlib.pyplot as plt
import pandas as pd

# Example data
months = pd.date_range(start='2023-01-01', periods=12, freq='M')
sales = [100, 120, 130, 150, 140, 160, 180, 200, 190, 210, 230, 240]

plt.plot(months, sales)
plt.title('Monthly Sales Revenue')
plt.xlabel('Month')
plt.ylabel('Sales Revenue ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3996\4132164446.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range(start='2023-01-01', periods=12, freq='M')

# %% [markdown]
# # Decompose the Data
#
# Using a statistical tool or library, we can decompose the time series into trend, seasonality, and residual components. Here’s an example using Python's statsmodels library:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Convert data to a pandas Series
data = pd.Series(sales, index=months)

# Perform additive decomposition
decomposition = seasonal_decompose(data, model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plotting the decomposed components
plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(data, label='Original')
plt.legend(loc='upper left')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='upper left')

plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='upper left')

plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       4 data = pd.Series(sales, index=months)
#       6 # Perform additive decomposition
# ----> 7 decomposition = seasonal_decompose(data, model='additive')
#       8 trend = decomposition.trend
#       9 seasonal = decomposition.seasonal
#
# File c:\Users\HP\anaconda3\envs\python_new\Lib\site-packages\statsmodels\tsa\seasonal.py:172, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     167         raise ValueError(
#     168             "You must specify a period or x must be a pandas object with "
#     169             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     170         )
#     171 if x.shape[0] < 2 * pfreq:
# --> 172     raise ValueError(
#     173         f"x must have 2 complete cycles requires {2 * pfreq} "
# ...
