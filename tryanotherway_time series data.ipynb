# %%
# Install finance library
! pip install yfinance

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
df_tsla = yf.download('TSLA', start='2020-04-01', end='2024-03-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_tsla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-01   33.599998   34.263332   31.673332   32.104000   32.104000
# 2020-04-02   32.068668   32.950668   29.760000   30.298000   30.298000
# 2020-04-03   33.966667   34.366001   31.226000   32.000668   32.000668
# 2020-04-06   34.080002   34.733334   33.197334   34.416000   34.416000
# 2020-04-07   36.333332   37.666668   35.489334   36.363335   36.363335
# ...                ...         ...         ...         ...         ...
# 2024-03-22  166.690002  171.199997  166.300003  170.830002  170.830002
# 2024-03-25  168.759995  175.240005  168.729996  172.630005  172.630005
# 2024-03-26  178.580002  184.250000  177.380005  177.669998  177.669998
# 2024-03-27  181.410004  181.910004  176.000000  179.830002  179.830002
# 2024-03-28  177.449997  179.570007  175.300003  175.789993  175.789993
#
#                Volume
# Date
# 2020-04-01  200298000
# 2020-04-02  297876000
# 2020-04-03  338431500
# ...

# %%
df_tsla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-04-01  33.599998  34.263332  31.673332  32.104000  32.104000  200298000
# 2020-04-02  32.068668  32.950668  29.760000  30.298000  30.298000  297876000
# 2020-04-03  33.966667  34.366001  31.226000  32.000668  32.000668  338431500
# 2020-04-06  34.080002  34.733334  33.197334  34.416000  34.416000  223527000
# 2020-04-07  36.333332  37.666668  35.489334  36.363335  36.363335  268797000

# %%
df_tsla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-22  166.690002  171.199997  166.300003  170.830002  170.830002
# 2024-03-25  168.759995  175.240005  168.729996  172.630005  172.630005
# 2024-03-26  178.580002  184.250000  177.380005  177.669998  177.669998
# 2024-03-27  181.410004  181.910004  176.000000  179.830002  179.830002
# 2024-03-28  177.449997  179.570007  175.300003  175.789993  175.789993
#
#                Volume
# Date
# 2024-03-22   75454700
# 2024-03-25   74228600
# 2024-03-26  113186200
# 2024-03-27   81804000
# 2024-03-28   77654800

# %%
! pip install matplotlib

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.0'

# %%
df_tsla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
# xlimit and ylimit
# We can provide the xlimit and ylimit in a  list or a tuple type
df_tsla['High'].plot(xlim= ['2020-01-01' ,'2021-09-01'], ylim=(0,900),figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla['High'].plot(xlim= ['2020-01-01' ,'2021-09-01'], ylim=(0,900),figsize=(12,4), ls='--', c="orange")
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla.index
# Out:
# DatetimeIndex(['2020-04-01', '2020-04-02', '2020-04-03', '2020-04-06',
#                '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-13',
#                '2020-04-14', '2020-04-15',
#                ...
#                '2024-03-15', '2024-03-18', '2024-03-19', '2024-03-20',
#                '2024-03-21', '2024-03-22', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28'],
#               dtype='datetime64[ns]', name='Date', length=1005, freq=None)

# %%
df_tsla.loc['2020-01-01' : '2021-09-01']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-01   33.599998   34.263332   31.673332   32.104000   32.104000
# 2020-04-02   32.068668   32.950668   29.760000   30.298000   30.298000
# 2020-04-03   33.966667   34.366001   31.226000   32.000668   32.000668
# 2020-04-06   34.080002   34.733334   33.197334   34.416000   34.416000
# 2020-04-07   36.333332   37.666668   35.489334   36.363335   36.363335
# ...                ...         ...         ...         ...         ...
# 2021-08-26  236.103333  238.466660  232.539993  233.720001  233.720001
# 2021-08-27  235.000000  238.333328  234.033340  237.306671  237.306671
# 2021-08-30  238.240005  243.666672  237.576660  243.636673  243.636673
# 2021-08-31  244.333328  246.796661  242.146667  245.240005  245.240005
# 2021-09-01  244.693329  247.330002  243.756668  244.696671  244.696671
#
#                Volume
# Date
# 2020-04-01  200298000
# 2020-04-02  297876000
# 2020-04-03  338431500
# ...

# %%
index = df_tsla.loc['2020-01-01' : '2021-09-01'].index

# %%
share_open = df_tsla.loc['2020-01-01': '2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-04-01     33.599998
# 2020-04-02     32.068668
# 2020-04-03     33.966667
# 2020-04-06     34.080002
# 2020-04-07     36.333332
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 359, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis = plt.subplots()
plt.tight_layout()
axis.plot(index, share_open)
figure.autofmt_xdate() # Preventing overlapping

# %% [markdown]
# ## Date time index

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1005 entries, 2020-04-01 to 2024-03-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1005 non-null   float64
#  1   High       1005 non-null   float64
#  2   Low        1005 non-null   float64
#  3   Close      1005 non-null   float64
#  4   Adj Close  1005 non-null   float64
#  5   Volume     1005 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 87.2 KB

# %%
df_tsla = df_tsla.reset_index()

# %%
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1005 non-null   datetime64[ns]
#  1   Open       1005 non-null   float64
#  2   High       1005 non-null   float64
#  3   Low        1005 non-null   float64
#  4   Close      1005 non-null   float64
#  5   Adj Close  1005 non-null   float64
#  6   Volume     1005 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 55.1 KB

# %%
# convert object/string format to datetime
pd.to_datetime(df_tsla['Date'])
# Out:
# 0      2020-04-01
# 1      2020-04-02
# 2      2020-04-03
# 3      2020-04-06
# 4      2020-04-07
#           ...
# 1000   2024-03-22
# 1001   2024-03-25
# 1002   2024-03-26
# 1003   2024-03-27
# 1004   2024-03-28
# Name: Date, Length: 1005, dtype: datetime64[ns]

# %%
df_tsla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-04-01   33.599998   34.263332   31.673332   32.104000   32.104000
# 1    2020-04-02   32.068668   32.950668   29.760000   30.298000   30.298000
# 2    2020-04-03   33.966667   34.366001   31.226000   32.000668   32.000668
# 3    2020-04-06   34.080002   34.733334   33.197334   34.416000   34.416000
# 4    2020-04-07   36.333332   37.666668   35.489334   36.363335   36.363335
# ...         ...         ...         ...         ...         ...         ...
# 1000 2024-03-22  166.690002  171.199997  166.300003  170.830002  170.830002
# 1001 2024-03-25  168.759995  175.240005  168.729996  172.630005  172.630005
# 1002 2024-03-26  178.580002  184.250000  177.380005  177.669998  177.669998
# 1003 2024-03-27  181.410004  181.910004  176.000000  179.830002  179.830002
# 1004 2024-03-28  177.449997  179.570007  175.300003  175.789993  175.789993
#
#          Volume
# 0     200298000
# 1     297876000
# ...

# %%
df_tsla = df_tsla.set_index('Date', drop=True)

# %%
df_tsla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-04-01  33.599998  34.263332  31.673332  32.104000  32.104000  200298000
# 2020-04-02  32.068668  32.950668  29.760000  30.298000  30.298000  297876000
# 2020-04-03  33.966667  34.366001  31.226000  32.000668  32.000668  338431500
# 2020-04-06  34.080002  34.733334  33.197334  34.416000  34.416000  223527000
# 2020-04-07  36.333332  37.666668  35.489334  36.363335  36.363335  268797000

# %% [markdown]
# ## Datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 6, 7, 11, 47, 12, 868791)

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
# time measurments
def add_num(num1, num2):
    return num1+num2

# %%
start_time = datetime.now()
num1 = 25
num2 = 63
add_num = num1+num2
end_time = datetime.now()
print('The time it takes is :' , end_time-start_time)
# Out:
# The time it takes is : 0:00:00

# %%
date = datetime(2021, 11, 21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.month
# Out:
# 11

# %%
date.weekday()
# Out:
# 6

# %% [markdown]
# ## Time Resampling

# %%
df_tsla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-04-01  33.599998  34.263332  31.673332  32.104000  32.104000  200298000
# 2020-04-02  32.068668  32.950668  29.760000  30.298000  30.298000  297876000
# 2020-04-03  33.966667  34.366001  31.226000  32.000668  32.000668  338431500
# 2020-04-06  34.080002  34.733334  33.197334  34.416000  34.416000  223527000
# 2020-04-07  36.333332  37.666668  35.489334  36.363335  36.363335  268797000

# %%
df_tsla.resample(rule='A')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\513246966.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A')

# %%
df_tsla.resample(rule='A').min()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\3050570558.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A').min()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-31   32.068668   32.950668   29.760000   30.298000   30.298000
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  110.349998  116.269997  108.239998  109.099998  109.099998
# 2023-12-31  103.000000  111.750000  101.809998  108.099998  108.099998
# 2024-12-31  163.160004  165.179993  160.509995  162.500000  162.500000
#
#               Volume
# Date
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  41864700
# 2023-12-31  65125200
# 2024-12-31  73178000

# %%
# Rule A means year end frequency
df_tsla.resample(rule='A').max()['Open'].plot()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\3432895050.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tsla.resample(rule='A').max()['Open'].plot()
# <Axes: xlabel='Date'>

# %%
# quartely start frequency
df_tsla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Business end frequency
df_tsla.resample(rule='BA').max()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\45563944.py:2: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tsla.resample(rule='BA').max()
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-30  396.516663  402.666656  378.679993  399.926666  399.926666
# 2023-12-29  296.040009  299.290009  289.519989  293.339996  293.339996
# 2024-12-31  250.080002  251.250000  244.410004  248.419998  248.419998
#
#                Volume
# Date
# 2020-12-31  666378600
# 2021-12-31  268189500
# 2022-12-30  221923300
# 2023-12-29  306590600
# 2024-12-31  198076800

# %%
# FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.

df_tsla.resample(rule='BA').max().plot()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\97903011.py:1: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tsla.resample(rule='BA').max().plot()
# <Axes: xlabel='Date'>

# %%
# Business quaters
df_tsla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-01   67.518669   72.512665   66.915337   71.987335   71.987335
# 2020-07-01  167.380005  167.496674  156.836670  166.106674  166.106674
# 2020-10-01  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-01-01  297.126678  300.133331  290.533325  294.363342  294.363342
# 2021-04-01  256.899994  260.263336  244.203339  254.106674  254.106674
# 2021-07-01  262.399994  266.333344  258.333344  263.786682  263.786682
# 2021-10-01  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-01-03  396.516663  402.666656  378.679993  399.926666  399.926666
# 2022-04-01  378.766663  384.290009  362.433319  381.816681  381.816681
# 2022-07-01  311.666656  314.666656  305.579987  309.320007  309.320007
# 2022-10-03  254.500000  257.500000  242.009995  249.440002  249.440002
# 2023-01-02  211.759995  217.649994  206.110001  214.240005  214.240005
# ...

# %%
## Plotting
# FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.

df_tsla['Open'].resample(rule='BYE').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
# monthly 
# FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead
df_tsla['Open'].resample(rule='ME').mean().plot(kind='bar', figsize=(16,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tsla['Open'].resample(rule='M').mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13276\1875486734.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tsla['Open'].resample(rule='M').mean()
# Date
# 2020-04-30     44.352985
# 2020-05-31     53.270667
# 2020-06-30     63.879576
# 2020-07-31     97.662666
# 2020-08-31    118.170762
# 2020-09-30    138.094286
# 2020-10-31    143.496818
# 2020-11-30    154.757665
# 2020-12-31    210.501363
# 2021-01-31    275.725791
# 2021-02-28    265.857542
# 2021-03-31    220.130724
# 2021-04-30    236.427620
# 2021-05-31    206.239336
# 2021-06-30    208.752122
# 2021-07-31    219.840953
# 2021-08-31    234.811213
# 2021-09-30    250.604284
# 2021-10-31    289.953491
# 2021-11-30    372.588890
# 2021-12-31    341.477726
# 2022-01-31    339.770000
# 2022-02-28    292.789474
# 2022-03-31    303.253333
# 2022-04-30    337.054169
# 2022-05-31    256.985554
# 2022-06-30    234.472539
# 2022-07-31    248.886668
# ...

# %% [markdown]
# ## Rolling

# %%
df_tsla['High'].head().rolling(10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
# Axis = 0 means we are doing for rows
# Axis = 1 means we are doing for colmns

df_tsla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2020-04-01          NaN
# 2020-04-02          NaN
# 2020-04-03          NaN
# 2020-04-06          NaN
# 2020-04-07          NaN
# 2020-04-08          NaN
# 2020-04-09          NaN
# 2020-04-13          NaN
# 2020-04-14          NaN
# 2020-04-15    39.260667
# 2020-04-16    40.897334
# 2020-04-17    42.768600
# 2020-04-20    44.435800
# 2020-04-21    45.984667
# 2020-04-22    47.111333
# 2020-04-23    48.289934
# 2020-04-24    49.326934
# 2020-04-27    50.310200
# 2020-04-28    50.731000
# 2020-04-29    51.064800
# Name: High, dtype: float64

# %%
df_tsla['High'].rolling(11).max().head(20)
# Out:
# Date
# 2020-04-01          NaN
# 2020-04-02          NaN
# 2020-04-03          NaN
# 2020-04-06          NaN
# 2020-04-07          NaN
# 2020-04-08          NaN
# 2020-04-09          NaN
# 2020-04-13          NaN
# 2020-04-14          NaN
# 2020-04-15          NaN
# 2020-04-16    50.630001
# 2020-04-17    51.663334
# 2020-04-20    51.663334
# 2020-04-21    51.663334
# 2020-04-22    51.663334
# 2020-04-23    51.663334
# 2020-04-24    51.663334
# 2020-04-27    53.299332
# 2020-04-28    53.666668
# 2020-04-29    53.666668
# Name: High, dtype: float64

# %%
df_tsla['Open : 30 days rolling']=df_tsla['Open'].rolling(30).mean()

# %%
df_tsla.head(31)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-04-01  33.599998  34.263332  31.673332  32.104000  32.104000  200298000
# 2020-04-02  32.068668  32.950668  29.760000  30.298000  30.298000  297876000
# 2020-04-03  33.966667  34.366001  31.226000  32.000668  32.000668  338431500
# 2020-04-06  34.080002  34.733334  33.197334  34.416000  34.416000  223527000
# 2020-04-07  36.333332  37.666668  35.489334  36.363335  36.363335  268797000
# 2020-04-08  36.946667  37.147331  35.555332  36.589333  36.589333  189840000
# 2020-04-09  37.472668  38.345333  37.140667  38.200001  38.200001  204750000
# 2020-04-13  39.344002  43.466667  38.702000  43.396667  43.396667  337131000
# 2020-04-14  46.598000  49.458668  46.161999  47.326000  47.326000  458647500
# 2020-04-15  49.466667  50.208668  47.333332  48.655334  48.655334  353655000
# 2020-04-16  47.796001  50.630001  47.114666  49.680668  49.680668  309868500
# ...

# %% [markdown]
# ## Smoothening

# %%
df_tsla[['Open', 'Open : 30 days rolling']].plot(figsize=(12, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Asignment
# ![image.png](attachment:image.png)
